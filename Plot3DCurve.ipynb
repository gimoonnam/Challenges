# %%
from mpl_toolkits.mplot3d import Axes3D

import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
t = np.linspace(0,4,200)
pi = np.pi
# x = np.cos(pi*t*0.5)*9. + np.sin(pi*t*1.5)*0.3 
# y = np.cos(pi*t*1.5+pi*0.45)*3.*(2+np.sin(pi*t)) + np.cos(pi*t*2.5)*0.5 
# z = np.cos(pi*t*0.5+ pi*1.3)*8.5 + np.sin(pi*t*2.)*0.6 

x = np.cos(pi*t*0.5)*2. + np.sin(pi*t*1.5)*0.3 
y = np.cos(pi*t*0.5+pi*1.45)*6. + np.cos(pi*t*2.5)*1.5 
z = np.cos(pi*t*0.5+pi*1.3)*7. + np.sin(pi*t*2.)*0.6

# %%
plt.rcParams['legend.fontsize']=10
plt.rcParams['figure.figsize']=(10,10)


fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(x,y,z)
plt.show()
